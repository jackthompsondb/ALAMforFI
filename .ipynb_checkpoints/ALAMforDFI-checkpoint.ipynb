# %% [markdown]
# <style>
#     body {
#         background-color: #222233 !important;
#         color: #AACCFF !important;
#     }
#
#     h1, h2, h3, h4, h5, h6, p, span, div, li, td, th, a, {
#         color: #AACCFF !important;
#     }
#
#     .highlight, .CodeMirror, .output_subarea,.output_area {
#         background-color: #f5f5f5 !important; /* Light background for code cells */
#         color: #000000 !important; /* Black text for code */
#     }
#
#     /* Optional: Style for code block borders to make them stand out */
#     .highlight pre, .CodeMirror pre {
#         border: 1px solid #cccccc;
#     }
# </style>

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.colors as mcolors
import seaborn as sns
from matplotlib.animation import FuncAnimation
from fbm import FBM
from IPython.core.display import HTML
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7804\2726195480.py in <module>
#       9 import seaborn as sns
#      10 from matplotlib.animation import FuncAnimation
# ---> 11 from fbm import FBM
#      12 from IPython.core.display import HTML
#
# ModuleNotFoundError: No module named 'fbm'

# %% [markdown]
# ## Table of Conents
# - [Introduction](#Introduction)
# - [Data Cleaning](#Data-Cleaning)
# - [Simulating Liquidity Providers](#simulating-liquidity-providers)
# - [Time Series Analysis](#time-series-analysis)
# - [Spreads](#spreads)
# - [Correlation](#correlation)
# - [Optimal Allocation](#optimal-allocation)
# - [Results](#results)

# %% [markdown]
# # Introduction
#
# This document contains the Adaptive Liquidity Allocation Model (ALAM) for Forex Investment.
#
# ALAM's aim is to optimise the allocation of liquidity providers (LPs) for any given time.
# ALAM is fully customisable for specific needs and purposes, for showcasing purposes I have simulated my own set of 10 liquidity providers.
# ALAM works accurate to the current time, and will also work with any forecasted data you are willing to rely on.
#
#
# ## Data Cleaning
#
# All historical data was extracted from forexsb.com/historical-forex-data
#
# I have defined a default frequency and pair here to apply for all further modelling in the document.
# Creating a smoothed dataset helped decrease my plot-time. For all calculations I used the raw data.

# %%
available_pairs = ['EURUSD', 'GBPUSD', 'AUDJPY', 'USDJPY']
pip_sizes = [0.0001,0.0001,0.01,0.01]
freq = ["M1","M5","M15","M30","H1","H4","D1"]

def_freq = freq[0]
def_pair = available_pairs[0]

def get_raw_forex_data(pair,frequency):
    data = pd.read_csv(rf"Forex\{pair}_{frequency}.csv",delimiter="\t")
    data.columns = ["Open","High","Low","Close","Volume","Spread"]
    return data

def get_smooth_forex_data(pair,frequency,smoothness):
    data = pd.read_csv(rf"Forex\{pair}_{frequency}.csv",delimiter="\t")
    data.columns = ["Open","High","Low","Close","Volume","Spread"]
    data_raw = data["Close"]
    data_smooth = data_raw.rolling(window=50).mean().dropna()
    
    x = np.arange(len(data_smooth))
    #p= np.polyfit(x,data_smooth, 32)
    #fit_line = np.polyval(p,x)
    return (x,data_smooth)

# %% [markdown]
# See the historical data for each of the pairs available.

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

for i,pair in enumerate(available_pairs):
    ax = axs[i // 2, i % 2]
    (ax.plot(get_smooth_forex_data(pair,def_freq,0)[0],get_smooth_forex_data(pair,def_freq,0)[1],label=pair))
    ax.set_title(f'{pair} Prices');ax.set_xlabel('Time (dt = 1minute)');ax.set_ylabel(f'Price({pair[:3]})')
    ax.grid();ax.legend()
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ## Simulating Liquidity Providers
#
# I have chosed to simulate 10 seperate LPs, each with unique average spread sizes to represent high/low spread liquidity providers.

# %%
def simulute_10_liquidity_providers(pair,freq,pip_size):
    qty_lps = 10
    base_price = (get_raw_forex_data(pair,freq)["Close"]).iloc[-1]
    avg_spread = (get_raw_forex_data(pair,freq)["Spread"].mean())*pip_size
    sigma = np.std(get_raw_forex_data(pair,freq)["Spread"])*pip_size
    LP_data = [] 
    for i in range(qty_lps):
        LP_ID = i+1
        spread_noise = abs(np.random.normal(0,sigma))
        spread_incr = LP_ID**0.75
        bid = round(base_price - spread_incr*(avg_spread/2+spread_noise),4)
        ask = round(base_price + spread_incr*(avg_spread/2+spread_noise),4)
        LP_data.append({"LP":f"LP_{LP_ID}","Spread":round(ask-bid,5),"Bid":bid,"Ask":ask})
    return LP_data
LP_data = simulute_10_liquidity_providers(def_pair,def_freq,pip_sizes[0])
LP_data
# Out:
# [{'LP': 'LP_1', 'Spread': 0.0011, 'Bid': 1.0864, 'Ask': 1.0875},
#  {'LP': 'LP_2', 'Spread': 0.0039, 'Bid': 1.085, 'Ask': 1.0889},
#  {'LP': 'LP_3', 'Spread': 0.003, 'Bid': 1.0854, 'Ask': 1.0884},
#  {'LP': 'LP_4', 'Spread': 0.0026, 'Bid': 1.0856, 'Ask': 1.0882},
#  {'LP': 'LP_5', 'Spread': 0.0019, 'Bid': 1.086, 'Ask': 1.0879},
#  {'LP': 'LP_6', 'Spread': 0.0036, 'Bid': 1.0851, 'Ask': 1.0887},
#  {'LP': 'LP_7', 'Spread': 0.0056, 'Bid': 1.0841, 'Ask': 1.0897},
#  {'LP': 'LP_8', 'Spread': 0.0025, 'Bid': 1.0857, 'Ask': 1.0882},
#  {'LP': 'LP_9', 'Spread': 0.0056, 'Bid': 1.0841, 'Ask': 1.0897},
#  {'LP': 'LP_10', 'Spread': 0.0074, 'Bid': 1.0832, 'Ask': 1.0906}]

# %% [markdown]
# ## Time Series Analysis
#
# Let's simulate a further 120 minutes (2 hours) of our market data to run our model on.
# To create an accurate forecast we first need to uncover some properties of our data using Time Series Analysis. Specifically, ACF and PACF plots.

# %%
horizon = 60*2
history = 60*6
TS_lastsixhour = (get_raw_forex_data(def_pair,def_freq)["Close"])[-history:]
TS_lastsixhour.index = pd.to_datetime(TS_lastsixhour.index)
n = horizon + len(TS_lastsixhour)
last_value = TS_lastsixhour.iloc[-1]  # Get the last yhat value

plot_acf(TS_lastsixhour,lags=50);
plot_pacf(TS_lastsixhour);

# %% [markdown]
# The Autocorrelation goes on for many lags, but we can see that it falls below the confidence interval at around 22, so lets select an MA(22).
# We can see a partial autocorrelation drops off after the second model, signifying a AR(2) process.
#
# Let's fit our ARIMA model.

# %%
model = ARIMA(TS_lastsixhour, order=(22, 0, 2))
fitted_model = model.fit()
forecast = fitted_model.simulate(nsimulations=horizon)
forecast = np.concatenate(([last_value],forecast))

simulated_time_index = pd.date_range(start=TS_lastsixhour.index[-1] + pd.DateOffset(minutes=1), periods=horizon+1, freq='min')
FCST_df = pd.DataFrame((pd.to_datetime(simulated_time_index),np.round(forecast,5))).T
FCST_df.columns = ["ds","y"]
DF_lastsixhour = pd.DataFrame((TS_lastsixhour.index,TS_lastsixhour)).T
DF_lastsixhour.columns = ["ds","y"]

plt.plot(DF_lastsixhour["ds"],DF_lastsixhour["y"],label="original")
plt.plot(FCST_df["ds"],FCST_df["y"],color="red",label="simulated")
plt.title(f"Historical Forex ({def_pair}) Data with Simulated Future")
plt.legend()
# Out:
# C:\Users\dbjac\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency min will be used.
#   self._init_dates(dates, freq)
# C:\Users\dbjac\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency min will be used.
#   self._init_dates(dates, freq)
# C:\Users\dbjac\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency min will be used.
#   self._init_dates(dates, freq)
# C:\Users\dbjac\AppData\Roaming\Python\Python312\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# This looks good, seems like a perfeclty natural progression with no extreme "market events".
# We will use this simulated data to allocated liquidity over.
#
# First, we need to create some variation/noise in the spreads for each liquidity provider.
#
# My first instinct was to use a Normal R.V as noise for each time step, but this was too chaotic, and not really a good replication of real world behaviour.
#
# Instead, i've gone with Fractional Brownian Motion; this provides a smoother variation in our noise, and even adds a trend. The trend will create overlaps of LPs' bids/asks, therefore changing the optimal decisions to be made over liquidity provision. Exactly what we need to test our model for.
#
# Below you can see the process of creating the noise, and then adding it to our simulated preference price (market price), since the spread of any LP always tends to encapsulate this value anyway, otherwise nobody would use them.

# %%
fig, axes = plt.subplots(3,1,)
f = FBM(n=120, hurst=0.3, length=pip_sizes[0])
smooth_random_series = f.fbm()
axes[0].plot(smooth_random_series,label="Fractional Brownian Motion",color="red")
axes[0].legend()

axes[1].plot(FCST_df["y"],label="Simulated Forex Data")
axes[1].legend()

random_mid = FCST_df["y"].values + smooth_random_series
axes[2].plot(random_mid,label="Simulated LP Midprice",color="purple")
axes[2].legend()

print(len(FCST_df["y"]))
print(len(smooth_random_series))
# Out:
# 121
# 121

# %% [markdown]
# ## Spreads
#
# Now for each liquidity provider, I track the importants variables such as Bid, Ask, Spread, Residual for each LP at each price point.
# And implementing a price impact proportional to the value invested. This reflects the real world condition where LPs will increase the spread for larger orders.

# %%
def live_simulute_liquidity_providers(LP_data,simulated_data,pip_sizes,init_cash):
    results = []
    
    spread_scale = (pip_sizes/100)*init_cash
    max_spread = np.max([LP["Spread"] for LP in LP_data])
    min_spread = np.min([LP["Spread"] for LP in LP_data])
    for i,LP in enumerate(LP_data):
        f = FBM(n=120, hurst=0.8, length=pip_sizes)
        smooth_random_series = f.fbm()
        spreads = []
        lp_evolution = []
        mids = (simulated_data["y"].values + smooth_random_series) + spread_scale
        base_spread = LP["Spread"]
        for t,price_points in enumerate(simulated_data["y"]):
            ask = mids[t] + base_spread/2 
            bid = ask - base_spread
            spreads.append(ask-bid)
            base_price = price_points
            lp_evolution.append({"LP":i+1,"Price":base_price,"Spread":ask-bid,"Bid":bid,"Ask":ask,"Mid":mids[t],"Residual":ask-base_price})
        results.append(lp_evolution)
    return results

init_cash = 50
simulated_data = FCST_df
lp_results = live_simulute_liquidity_providers(LP_data,simulated_data,pip_sizes[0],init_cash)

for lp_evolution in lp_results:
    asks = [entry["Ask"] for entry in lp_evolution]  
    plt.plot(FCST_df["ds"], asks)  
    #bids = [entry["Bid"] for entry in lp_evolution]  
    #plt.plot(FCST_df["ds"], bids) 
plt.plot(FCST_df["ds"],FCST_df["y"],color="red",lw=2,label="preference price")
plt.title("LPs Ask Price over time, overplotted with preference price")
plt.legend()

# %% [markdown]
# We can see above the evolution of the Ask prices for each LP at each time-frame. We can see that the residuals are not constant, and that at different times we will see a more optimal choice of LPs.
#
# Now let's visualise the residual of each LP over time.

# %%
def plot_liquidity_provider_spreads(results):
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')
    all_res = [entry['Residual'] for lp_data in results for entry in lp_data]
    norm = mcolors.Normalize(vmin=min(all_res), vmax=max(all_res))
    colormap = plt.cm.coolwarm

    for i, lp_data in enumerate(results):
        time_points = range(len(lp_data))
        res_values = [entry['Residual'] for entry in lp_data]
        bid_values = [entry['Bid'] for entry in lp_data]
        ask_values = [entry['Ask'] for entry in lp_data]
        mids = [(bid + ask) / 2 for bid, ask in zip(bid_values, ask_values)]

        colors = colormap(norm(res_values))
        ax.plot(time_points, [i]*len(time_points), res_values,color=colors[-1] ,label=f"LP_{i+1} Mid",lw=1)

        # Optionally, plot Bid and Ask over time as separate lines for each LP
        #ax.plot(time_points, [i]*len(time_points), bid_values,color=colors[-1] ,linestyle="--" )
        #ax.plot(time_points, [i]*len(time_points), ask_values,color=colors[-1] ,linestyle="--")

    ax.set_xlabel('Time')
    ax.set_ylabel('Liquidity Provider (LP)')
    ax.set_zlabel('Residual')
    ax.legend()
    plt.show()

plot_liquidity_provider_spreads(lp_results)

# %% [markdown]
# ## Correlation
#
# Residuals & Spreads are no the only important factor to consider when optimising liquidity allocation.
#
# Correlation is also important. If you select two similarly correlated then you are not diversifying your risk appropriately.
# This is for risk reduction, so if your selected LPs decide to raise costs simultaneously (which is more likely with highly correlated LPs) then you will end up paying more.
# Similarly, the price impact may be reduced if you spread liquidity over LPs with different hedging and risk allocation strategies.

# %%
corr_matrices_all = []
for time_step in lp_results:
    residuals = []
    for lp_entry in time_step:
        lp_name = lp_entry["LP"]
        residual = lp_entry['Residual']
        residuals.append({'LP': lp_name, 'Residual': residual})
  
    df = residuals
    corr_matrices_all.append(df)

residual_columnised = pd.DataFrame(columns=["LP_1", "LP_2", "LP_3", "LP_4", "LP_5", "LP_6", "LP_7", "LP_8", "LP_9", "LP_10"])
index = 0
for LP in corr_matrices_all:
    col_dat = []
    for time_step in LP:
        col_dat.append(time_step["Residual"])
    residual_columnised[f"LP_{index+1}"] = col_dat
    index += 1

cumulative_corr_matrices = []

for i in range(1, len(residual_columnised) + 1):
    if i == 1 or i == 2:
            correlation_matrix = pd.DataFrame(0, index=residual_columnised.columns, columns=residual_columnised.columns)
    else:
        cumulative_data = residual_columnised.iloc[:i]
        correlation_matrix = cumulative_data.corr().abs()
        correlation_matrix = (correlation_matrix + 1) / 2
    cumulative_corr_matrices.append(correlation_matrix)


plt.figure(figsize=(10, 8))
sns.heatmap(cumulative_corr_matrices[-1], annot=True, fmt=".2f", cmap="viridis", square=True)
plt.title(f'Correlation Matrix of LP Residuals at Time = {horizon}')
plt.show()

# %% [markdown]
# Above is our correlation matrix at time t = T
#
# And below you can see the evolution of this matrix over all time frames.

# %%
#fig, ax = plt.subplots(figsize=(8, 6))
cax = ax.matshow(np.zeros((10, 10)), cmap="viridis", vmin=-1, vmax=1)
def update(frame):
    corr_matrix = cumulative_corr_matrices[frame]
    ax.clear()
    ax.matshow(corr_matrix, cmap="viridis", vmin=-1, vmax=1)
    ax.set_title(f"Time Step: {frame + 1}")
    
fig.colorbar(cax)
#anim = FuncAnimation(fig, update, frames=len(cumulative_corr_matrices), interval=500, repeat=False)
#anim.save('correlation_animation.gif', writer='pillow')

# %% [markdown]
# ![Correlation Over Time](https://i.giphy.com/media/v1.Y2lkPTc5MGI3NjExZGJ4aXc2ZHd4eHFnZXR5ZHZsazY4c2N1NXJ5cnk4MDlrazhyNzRhbiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/h1y9ncpniBp0RdRP85/giphy.gif)

# %% [markdown]
# ## Optimal Allocation
#
# Now we have analysed two key factors for our allocation.
# We need to decide which LPs to select.
#
# To do this ALAM weights the spread as slightly more important (x1.25), to reduce immediate costs. And also takes into account the avg. correlation for each LP at the given time.
# ALAM normalises the residuals at time t, and since our correlations are already normalised, we can easily calculate and define a simple score metric. Here we want a low residual, and a low correlation.
#
# Here I have decided to select top-3 LPs under this criteria. However, you can set the parameter to whatever you desire.

# %%
def optimal_evolutions(residual_columnised,cumulative_corr_matrices,num_to_select=3):
    optimal_allocations = []
    for i in range(len(residual_columnised)):
        LP_score = []
        for LP in residual_columnised:
            corr_index = int((LP.split("_")[1]))
            res_score = residual_columnised[LP][i]
            corr_scores = (cumulative_corr_matrices[i].mean(axis=0).values)
            corr_scores = corr_scores[corr_index-1]
            res_normed = (res_score-min(residual_columnised[LP]))/(max(residual_columnised[LP])-min(residual_columnised[LP]))
            total_score = (-res_normed*1.25)+(-corr_scores)
            LP_score.append(total_score)
        LP_sorted = np.argsort(LP_score)[:num_to_select]
        optimal_allocations.append(LP_sorted)
    return optimal_allocations

optimal_allocations = optimal_evolutions(residual_columnised,cumulative_corr_matrices,num_to_select=3)
optimal_allocations[:10]
# Out:
# [array([0, 2, 4], dtype=int64),
#  array([0, 7, 2], dtype=int64),
#  array([0, 7, 2], dtype=int64),
#  array([0, 1, 4], dtype=int64),
#  array([0, 4, 1], dtype=int64),
#  array([0, 4, 1], dtype=int64),
#  array([1, 7, 0], dtype=int64),
#  array([1, 4, 0], dtype=int64),
#  array([2, 4, 0], dtype=int64),
#  array([2, 7, 0], dtype=int64)]

# %% [markdown]
# ## Results

# %% [markdown]
# Let's view a distribution of how often each LP was selected.

# %%
lp_counts = {f"{i}": 0 for i in range(10)}  # Assuming 10 LPs

for allocation in optimal_allocations:
    for lp in allocation:
        lp_counts[f"{lp}"] += 1

plt.bar(lp_counts.keys(), lp_counts.values())
plt.title("Number of Times Each LP is Selected")
plt.xlabel("Liquidity Providers (LP)")
plt.ylabel("Selection Count")
plt.show()

# %% [markdown]
# And here we can see for each time step the set of LPs selected as most optimal under our metric.

# %%
#fig, ax = plt.subplots(figsize=(10, 6))
lp_labels = [f"LP_{i+1}" for i in range(10)]
bars = ax.bar(lp_labels, [0] * 10)  
ax.set_ylim(0, 1.1) 
ax.set_title('LP Selection Over Time')
ax.set_xlabel('Liquidity Providers')
ax.set_ylabel('Selected (1) / Not Selected (0)')
bars = ax.bar(np.arange(10), np.zeros(10), color='skyblue', edgecolor='darkblue')

def update(frame):
    ax.set_title(f"Time Step: {frame + 1}")
    selection = [1 if i in optimal_allocations[frame] else 0 for i in range(10)]
    
    for i, bar in enumerate(bars):
        bar.set_height(selection[i]) 

#anim = FuncAnimation(fig, update, frames=len(optimal_allocations), interval=500, repeat=False)
#anim.save('LiquidityAllocation.gif', writer='pillow')
#plt.show()

# %% [markdown]
# ![Liquidity Correlation GIF](https://i.giphy.com/media/v1.Y2lkPTc5MGI3NjExczIxdTZkbXM3eWU2bmdrYjlxazAwZHVlM2gwNXVtcDduY2t3aXR5aCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/96CwpnFUWRwoJomWnX/giphy.gif)
